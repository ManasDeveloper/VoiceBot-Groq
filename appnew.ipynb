# %%
# !pip install speechrecognition
# Out:
# ...
#   Using cached SpeechRecognition-3.10.4-py2.py3-none-any.whl.metadata (28 kB)
# ...
# Using cached SpeechRecognition-3.10.4-py2.py3-none-any.whl (32.8 MB)
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import speech_recognition as sr

# %%
# !pip install pyttsx3
# Out:
# ...
#   Using cached pyttsx3-2.91-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyobjc-10.3.1-py3-none-any.whl.metadata (26 kB)
# ...
#   Using cached pyobjc_core-10.3.1-cp310-cp310-macosx_10_9_universal2.whl.metadata (2.5 kB)
# ...
#   Using cached pyobjc_framework_AddressBook-10.3.1-cp36-abi3-macosx_11_0_universal2.whl.metadata (2.4 kB)
# ...
#   Using cached pyobjc_framework_AppleScriptKit-10.3.1-py2.py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached pyobjc_framework_ApplicationServices-10.3.1-cp310-cp310-macosx_10_9_universal2.whl.metadata (2.6 kB)
# ...
#   Using cached pyobjc_framework_Automator-10.3.1-cp36-abi3-macosx_11_0_universal2.whl.metadata (2.5 kB)
# ...
#   Using cached pyobjc_framework_CFNetwork-10.3.1-cp36-abi3-macosx_11_0_universal2.whl.metadata (2.5 kB)
# ...
#   Using cached pyobjc_framework_Cocoa-10.3.1-cp310-cp310-macosx_10_9_universal2.whl.metadata (2.3 kB)
# ...
#   Using cached pyobjc_framework_CoreAudio-10.3.1-cp310-cp310-macosx_10_9_universal2.whl.metadata (2.2 kB)
# ...

# %%
# !pip install pyaudio
# Out:
# ...
#   Using cached PyAudio-0.2.14.tar.gz (47 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for pyaudio: filename=PyAudio-0.2.14-cp310-cp310-macosx_11_0_arm64.whl size=24113 sha256=0c2bdbde1a99523094181bf04cbb996de928fb6534b273160c90fef7d6af6473
#   Stored in directory: /Users/manas/Library/Caches/pip/wheels/d6/21/f4/0b51d41ba79e51b16295cbb096ec49f334792814d545b508c5
# Successfully built pyaudio
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
